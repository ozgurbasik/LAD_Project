# %% [markdown]
# # View & Modify Model Architecture

# %% [markdown]
# ## YOLO V8 (n)

# %%
from ultralytics import YOLO

# Load the YOLOv8 Nano model from your local path
model = YOLO("./Models/yolov8n.pt")

# %%
# Print model architecture to inspect the layers
print(model.model)

# %% [markdown]
# ## YOLO V11 (n)

# %%
from ultralytics import YOLO

# Load the YOLOv8 Nano model from your local path
model = YOLO("./Models/yolo11n.pt")

# %%
# Print model architecture to inspect the layers
print(model.model)

# %% [markdown]
# ## YOLO V11 (s)

# %%
from ultralytics import YOLO

# Load the YOLOv8 Nano model from your local path
model = YOLO("./Models/yolo11s.pt")

# %%
# Print model architecture to inspect the layers
print(model.model)
