# %% [markdown]
# # Testing imports / Dependencies / Library Versions

# %% [markdown]
# PyTorch Test

# %%
# Importing PyTorch
import torch
import torchvision
import pycuda.driver as cuda
import sys
import pycuda.autoinit
from pycuda.compiler import SourceModule
import numpy as np
#sys.path
print(f"CUDA Driver Version: {cuda.get_driver_version()}")
print(f"Device Count: {cuda.Device.count()}")

for i in range(cuda.Device.count()):
    dev = cuda.Device(i)
    print(f"Device {i}: {dev.name()}")
    print(f"  Total Memory: {dev.total_memory() / (1024 * 1024)} MB")


# PyTorch version and CUDA information
print(f"PyTorch Version: {torch.__version__}")
print(f"Torchvision Version: {torchvision.__version__}")
print(f"CUDA is available: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"CUDA Version: {torch.version.cuda}")
    print(f"CUDA Device: {torch.cuda.get_device_name(0)}")

    # Test CUDA with a simple tensor operation
    x = torch.tensor([1.0, 2.0, 3.0]).cuda()
    print(f"\nTest tensor on CUDA:")
    print(f"Tensor: {x}")
    print(f"Device: {x.device}")

# %% [markdown]
# TensorFlow Test

# %%
# Importing TensorFlow
import tensorflow as tf

# TensorFlow version check
print(f"TensorFlow Version: {tf.__version__}")
print(f"TensorFlow is available: {tf.test.is_built_with_cuda()}")

# Test: Create a TensorFlow tensor
x_tf = tf.constant([1.0, 2.0, 3.0])
print(f"TensorFlow tensor: {x_tf}")

# %% [markdown]
# NumPy & Pandas & Matplotlib Test

# %%
# Importing NumPy
import numpy as np
# Importing Pandas
import pandas as pd
# Importing Matplotlib
import matplotlib

# NumPy version check
print(f"NumPy Version: {np.__version__}")

# Test: Create a NumPy array
arr = np.array([1, 2, 3])
print(f"NumPy Array: {arr}")

# Pandas version check
print(f"Pandas Version: {pd.__version__}")

# Test: Create a simple DataFrame
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
print(f"Sample DataFrame:\n{df}")

# Matplotlib version check
print(f"Matplotlib Version: {matplotlib.__version__}")

# Test: Plot a simple graph
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 5, 6])
plt.title('Simple Plot')
plt.show()

# %% [markdown]
# Seaborn Test

# %%
# Importing Seaborn
import seaborn as sns

# Seaborn version check
print(f"Seaborn Version: {sns.__version__}")

# Test: Create a Seaborn plot
sns.set(style="whitegrid")
tips = sns.load_dataset("tips")
sns.boxplot(x="day", y="total_bill", data=tips)
plt.show()

# %% [markdown]
# Scikit-learn Test

# %%
# Importing Scikit-learn
import sklearn

# Scikit-learn version check
print(f"Scikit-learn Version: {sklearn.__version__}")

# Test: Train a simple classifier on Iris dataset
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

iris = load_iris()
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.2)
clf = RandomForestClassifier()
clf.fit(X_train, y_train)
print(f"Scikit-learn RandomForest accuracy: {clf.score(X_test, y_test)}")

# %% [markdown]
# Keras Test

# %%
# Importing Keras
import keras

# Keras version check
print(f"Keras Version: {keras.__version__}")

# Test: Create a simple Keras model
model = keras.Sequential([keras.layers.Dense(3, input_dim=1, activation='relu')])
print(f"Keras model summary: {model.summary()}")
